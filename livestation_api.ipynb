# %% [markdown]
# <a href="https://colab.research.google.com/github/park-moonkyu/livestaton/blob/main/livestation_api.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sys
import os
import hashlib
import hmac
import base64
import requests
import time
import json

# 채널 삭제

#Time Stamp 생성
timestamp = int(time.time() * 1000)
timestamp = str(timestamp)			

#Access Key
access_key = "cQryoIZzGPyeZbWK7Yin"

#Secret_key
secret_key = "x0ur5FbIfnz0OfduXyevWAjj4cS2XSC5ueHhjwdG"

#Singature Key 생성
def	make_signature():
	timestamp = int(time.time() * 1000)
	timestamp = str(timestamp)

	access_key = "cQryoIZzGPyeZbWK7Yin"			
	secret_key = "x0ur5FbIfnz0OfduXyevWAjj4cS2XSC5ueHhjwdG"	
	secret_key = bytes(secret_key, 'UTF-8')

	method = "DELETE"
	uri = "/api/v2/channels/ls-20210210102124-9f8di"

	message = method + " " + uri + "\n" + timestamp + "\n" + access_key
	message = bytes(message, 'UTF-8')
	signingKey = base64.b64encode(hmac.new(secret_key, message, digestmod=hashlib.sha256).digest())
	return signingKey


URL = 'https://livestation.apigw.ntruss.com/api/v2/channels/ls-20210210102124-9f8di' 

headers = {'x-ncp-apigw-timestamp': timestamp, 
           'x-ncp-iam-access-key': access_key,
           'x-ncp-apigw-signature-v2': make_signature(), 
           'x-ncp-region_code': "KR",
           'Content-Type': 'application/json'
           }
# 'Content-Type': 'application/json; UTF-8'
res = requests.delete(URL, headers=headers)
res.request # 내가 보낸 request 객체에 접근 가능 
res.json()
# Out:
# {'content': {'alertOn': False,
#   'alertOptions': {'alertChangeStatus': False,
#    'alertReStreamFail': False,
#    'alertVodUploadFail': False},
#   'cdn': {'cdnDomain': 'axmnmqvdygks6032910.cdn.ntruss.com',
#    'cdnType': 'CDN_PLUS',
#    'instanceNo': '6032910',
#    'serviceName': 'cdn-ls-20210210102124-9f8di',
#    'statusName': 'running'},
#   'channelId': 'ls-20210210102124-9f8di',
#   'channelName': 'make_Process',
#   'channelStatus': 'DELETED',
#   'createdTime': 1612920085000,
#   'immediateOnAir': False,
#   'instanceNo': 6032909,
#   'isRecording': False,
#   'outputProtocol': 'HLS, DASH',
#   'publishUrl': 'rtmp://rtmp-ls2-k1.video.media.ntruss.com:8080/relay',
#   'qualitySetId': 531,
#   'qualitySetName': '5532',
#   'streamKey': 'zccqdlkuopukkl1d042om7vz29gg3ame',
#   'totalPublishSeconds': 0,
#   'useDVR': False}}

# %% [markdown]
# 메인

# %%
import sys
import os
import hashlib
import hmac
import base64
import requests
import time
import json

def channel_spec():
  

  timestamp = int(time.time() * 1000)
  timestamp = str(timestamp)			

 
  access_key = "cQryoIZzGPyeZbWK7Yin"
  secret_key = "x0ur5FbIfnz0OfduXyevWAjj4cS2XSC5ueHhjwdG"

  def	make_signature():
    timestamp = int(time.time() * 1000)
    timestamp = str(timestamp)

    access_key = "cQryoIZzGPyeZbWK7Yin"			
    secret_key = "x0ur5FbIfnz0OfduXyevWAjj4cS2XSC5ueHhjwdG"	
    secret_key = bytes(secret_key, 'UTF-8')

    method = "GET"
    uri = "/api/v2/channels/ls-20210119171141-j4Tn2"

    message = method + " " + uri + "\n" + timestamp + "\n" + access_key
    message = bytes(message, 'UTF-8')
    signingKey = base64.b64encode(hmac.new(secret_key, message, digestmod=hashlib.sha256).digest())
    return signingKey


  URL = 'https://livestation.apigw.ntruss.com/api/v2/channels/ls-20210119171141-j4Tn2' 

  headers = {'x-ncp-apigw-timestamp': timestamp, 
            'x-ncp-iam-access-key': access_key,
            'x-ncp-apigw-signature-v2': make_signature(), 
            'x-ncp-region_code': "KR"
            }
  # 'Content-Type': 'application/json; UTF-8'
  res = requests.get(URL, headers=headers)
  res.request # 내가 보낸 request 객체에 접근 가능
  print(res.json())


def channel_view():
  #Time Stamp 생성
  timestamp = int(time.time() * 1000)
  timestamp = str(timestamp)			

  #Access Key
  access_key = "cQryoIZzGPyeZbWK7Yin"

  #Secret_key
  secret_key = "x0ur5FbIfnz0OfduXyevWAjj4cS2XSC5ueHhjwdG"

  #Singature Key 생성
  def	make_signature():
    timestamp = int(time.time() * 1000)
    timestamp = str(timestamp)

    access_key = "cQryoIZzGPyeZbWK7Yin"			
    secret_key = "x0ur5FbIfnz0OfduXyevWAjj4cS2XSC5ueHhjwdG"	
    secret_key = bytes(secret_key, 'UTF-8')

    method = "GET"
    uri = "/api/v2/channels"

    message = method + " " + uri + "\n" + timestamp + "\n" + access_key
    message = bytes(message, 'UTF-8')
    signingKey = base64.b64encode(hmac.new(secret_key, message, digestmod=hashlib.sha256).digest())
    return signingKey


  URL = 'https://livestation.apigw.ntruss.com/api/v2/channels' 

  headers = {'x-ncp-apigw-timestamp': timestamp, 
            'x-ncp-iam-access-key': access_key,
            'x-ncp-apigw-signature-v2': make_signature(), 
            'x-ncp-region_code': "KR"
            }
  # 'Content-Type': 'application/json; UTF-8'
  res = requests.get(URL, headers=headers)
  res.request # 내가 보낸 request 객체에 접근 가능 
  print(res.json())
  

def setQualityID():
  
  #Time Stamp 생성
  timestamp = int(time.time() * 1000)
  timestamp = str(timestamp)         

  #Access Key
  access_key = "cQryoIZzGPyeZbWK7Yin"

  #Secret_key
  secret_key = "x0ur5FbIfnz0OfduXyevWAjj4cS2XSC5ueHhjwdG"

  #Singature Key 생성
  def   make_signature():
    timestamp = int(time.time() * 1000)
    timestamp = str(timestamp)

    access_key = "cQryoIZzGPyeZbWK7Yin"         
    secret_key = "x0ur5FbIfnz0OfduXyevWAjj4cS2XSC5ueHhjwdG"   
    secret_key = bytes(secret_key, 'UTF-8')

    method = "GET"
    uri = "/api/v2/qualitySets"

    message = method + " " + uri + "\n" + timestamp + "\n" + access_key
    message = bytes(message, 'UTF-8')
    signingKey = base64.b64encode(hmac.new(secret_key, message, digestmod=hashlib.sha256).digest())
    return signingKey


  URL = 'https://livestation.apigw.ntruss.com/api/v2/qualitySets' 

  headers = {'x-ncp-apigw-timestamp': timestamp, 
            'x-ncp-iam-access-key': access_key,
            'x-ncp-apigw-signature-v2': make_signature(), 
            'x-ncp-region_code': "KR",
            }
  data={  
    "channelName" : "testchannel",
    "cdn" : {
        "createCdn" : True,
        "cdnType" : "CDN_PLUS"
    },
    "qualitySetId" : 12345,
    "useDvr" : True,
    "immediateOnAir" : True,
    "timemachineMin" : 360
  }

  # 'Content-Type': 'application/json; UTF-8'
  res = requests.get(URL, headers=headers)
  res.request # 내가 보낸 request 객체에 접근 가능 
  res.json()



def make_channel():
  #Time Stamp 생성
  timestamp = int(time.time() * 1000)
  timestamp = str(timestamp)			

  #Access Key
  access_key = "cQryoIZzGPyeZbWK7Yin"

  #Secret_key
  secret_key = "x0ur5FbIfnz0OfduXyevWAjj4cS2XSC5ueHhjwdG"

  #Singature Key 생성
  def	make_signature():
    timestamp = int(time.time() * 1000)
    timestamp = str(timestamp)

    access_key = "cQryoIZzGPyeZbWK7Yin"			
    secret_key = "x0ur5FbIfnz0OfduXyevWAjj4cS2XSC5ueHhjwdG"	
    secret_key = bytes(secret_key, 'UTF-8')

    method = "POST"
    uri = "/api/v2/channels"

    message = method + " " + uri + "\n" + timestamp + "\n" + access_key
    message = bytes(message, 'UTF-8')
    signingKey = base64.b64encode(hmac.new(secret_key, message, digestmod=hashlib.sha256).digest())
    return signingKey


  URL = 'https://livestation.apigw.ntruss.com/api/v2/channels' 

  headers = {'x-ncp-apigw-timestamp': timestamp, 
            'x-ncp-iam-access-key': access_key,
            'x-ncp-apigw-signature-v2': make_signature(), 
            'x-ncp-region_code': "KR",
            'Content-Type': 'application/json'
            }
  data={  
    "channelName" : name,
    "cdn" : {
        "createCdn" : True,
        "cdnType" : "CDN_PLUS"
    },
    "qualitySetId" : 531,
    "useDvr" : False
  }

  # 'Content-Type': 'application/json; UTF-8'
  res = requests.post(URL, headers=headers,data=json.dumps(data))
  res.request # 내가 보낸 request 객체에 접근 가능 
  res.json()

def channel_delete():
  #Time Stamp 생성
  timestamp = int(time.time() * 1000)
  timestamp = str(timestamp)			

  #Access Key
  access_key = "cQryoIZzGPyeZbWK7Yin"

  #Secret_key
  secret_key = "x0ur5FbIfnz0OfduXyevWAjj4cS2XSC5ueHhjwdG"

  #Singature Key 생성
  def	make_signature():
    timestamp = int(time.time() * 1000)
    timestamp = str(timestamp)

    access_key = "cQryoIZzGPyeZbWK7Yin"			
    secret_key = "x0ur5FbIfnz0OfduXyevWAjj4cS2XSC5ueHhjwdG"	
    secret_key = bytes(secret_key, 'UTF-8')

    method = "DELETE"
    uri = "/api/v2/channels/ls-20210210141842-1tnKV"

    message = method + " " + uri + "\n" + timestamp + "\n" + access_key
    message = bytes(message, 'UTF-8')
    signingKey = base64.b64encode(hmac.new(secret_key, message, digestmod=hashlib.sha256).digest())
    return signingKey


  URL = 'https://livestation.apigw.ntruss.com/api/v2/channels/ls-20210210141842-1tnKV' 

  headers = {'x-ncp-apigw-timestamp': timestamp, 
            'x-ncp-iam-access-key': access_key,
            'x-ncp-apigw-signature-v2': make_signature(), 
            'x-ncp-region_code': "KR",
            'Content-Type': 'application/json'
            }
  # 'Content-Type': 'application/json; UTF-8'
  res = requests.delete(URL, headers=headers)
  res.request # 내가 보낸 request 객체에 접근 가능 
  res.json()
if __name__ == '__main__':

  channel_delete()

  time.sleep(20)
  name=""
  make_channel()

# %% [markdown]
# 채널 목록 검색

# %%
import sys
import os
import hashlib
import hmac
import base64
import requests
import time

#Time Stamp 생성
timestamp = int(time.time() * 1000)
timestamp = str(timestamp)			

#Access Key
access_key = "cQryoIZzGPyeZbWK7Yin"

#Secret_key
secret_key = "x0ur5FbIfnz0OfduXyevWAjj4cS2XSC5ueHhjwdG"

#Singature Key 생성
def	make_signature():
	timestamp = int(time.time() * 1000)
	timestamp = str(timestamp)

	access_key = "cQryoIZzGPyeZbWK7Yin"			
	secret_key = "x0ur5FbIfnz0OfduXyevWAjj4cS2XSC5ueHhjwdG"	
	secret_key = bytes(secret_key, 'UTF-8')

	method = "GET"
	uri = "/api/v2/channels"

	message = method + " " + uri + "\n" + timestamp + "\n" + access_key
	message = bytes(message, 'UTF-8')
	signingKey = base64.b64encode(hmac.new(secret_key, message, digestmod=hashlib.sha256).digest())
	return signingKey


URL = 'https://livestation.apigw.ntruss.com/api/v2/channels' 

headers = {'x-ncp-apigw-timestamp': timestamp, 
           'x-ncp-iam-access-key': access_key,
           'x-ncp-apigw-signature-v2': make_signature(), 
           'x-ncp-region_code': "KR"
           }
# 'Content-Type': 'application/json; UTF-8'
res = requests.get(URL, headers=headers)
res.request # 내가 보낸 request 객체에 접근 가능 
res.json()
# Out:
# {'content': [{'alertOn': False,
#    'alertOptions': {'alertChangeStatus': False,
#     'alertReStreamFail': False,
#     'alertVodUploadFail': False},
#    'cdn': {'cdnDomain': 'zqwmcgzdrpuu5894645.cdn.ntruss.com',
#     'cdnType': 'CDN_PLUS',
#     'instanceNo': '5894645',
#     'serviceName': 'cdn-ls-20210120112249-7i527',
#     'statusName': 'running'},
#    'channelId': 'ls-20210120112249-7i527',
#    'channelName': 'youtube',
#    'channelStatus': 'READY',
#    'createdTime': 1611109370000,
#    'immediateOnAir': True,
#    'instanceNo': 5894644,
#    'isRecording': True,
#    'outputProtocol': 'HLS, DASH',
#    'publishUrl': 'rtmp://rtmp-ls2-k1.video.media.ntruss.com:8080/relay',
#    'qualitySetId': 5,
#    'qualitySetName': '480p-set',
#    'streamKey': 'xizohs4yngxuuu1qcinuk7e85ky75l89',
#    'timemachineMin': 360,
#    'totalPublishSeconds': 0,
#    'useDVR': True},
#   {'alertOn': False,
#    'alertOptions': {'alertChangeStatus': False,
#     'alertReStreamFail': False,
# ...

# %% [markdown]
# Service URL 조회

# %%
import sys
import os
import hashlib
import hmac
import base64
import requests
import time

#Time Stamp 생성
timestamp = int(time.time() * 1000)
timestamp = str(timestamp)			

#Access Key
access_key = "cQryoIZzGPyeZbWK7Yin"

#Secret_key
secret_key = "x0ur5FbIfnz0OfduXyevWAjj4cS2XSC5ueHhjwdG"

#Singature Key 생성
def	make_signature():
	timestamp = int(time.time() * 1000)
	timestamp = str(timestamp)

	access_key = "cQryoIZzGPyeZbWK7Yin"			
	secret_key = "x0ur5FbIfnz0OfduXyevWAjj4cS2XSC5ueHhjwdG"	
	secret_key = bytes(secret_key, 'UTF-8')

	method = "GET"
	uri = "/api/v2/channels/ls-20210119171141-j4Tn2/serviceUrls?serviceUrlType=GENERAL"

	message = method + " " + uri + "\n" + timestamp + "\n" + access_key
	message = bytes(message, 'UTF-8')
	signingKey = base64.b64encode(hmac.new(secret_key, message, digestmod=hashlib.sha256).digest())
	return signingKey


URL = 'https://livestation.apigw.ntruss.com/api/v2/channels/ls-20210119171141-j4Tn2/serviceUrls?serviceUrlType=GENERAL' 

headers = {'x-ncp-apigw-timestamp': timestamp, 
           'x-ncp-iam-access-key': access_key,
           'x-ncp-apigw-signature-v2': make_signature(), 
           'x-ncp-region_code': "KR"
           }

res = requests.get(URL, headers=headers)
res.request # 내가 보낸 request 객체에 접근 가능 
res.json()

#print(url_4800['url'])
# Out:
# {'content': [{'audioBitrate': '128000',
#    'name': '480p-16-9',
#    'resolution': '854x480',
#    'url': 'https://uteoxnpxynnv5889560.cdn.ntruss.com/live/video/ls-20210119171141-j4Tn2/480p-16-9/playlist.m3u8',
#    'videoBitrate': '1200000'},
#   {'audioBitrate': '96000',
#    'name': '360p-16-9',
#    'resolution': '640x360',
#    'url': 'https://uteoxnpxynnv5889560.cdn.ntruss.com/live/video/ls-20210119171141-j4Tn2/360p-16-9/playlist.m3u8',
#    'videoBitrate': '800000'},
#   {'audioBitrate': '192000',
#    'name': 'audio-192k',
#    'url': 'https://uteoxnpxynnv5889560.cdn.ntruss.com/live/video/ls-20210119171141-j4Tn2/audio-192k/playlist.m3u8'},
#   {'name': 'ABR',
#    'url': 'https://uteoxnpxynnv5889560.cdn.ntruss.com/live/video/ls-20210119171141-j4Tn2/playlist.m3u8'},
#   {'name': 'dash',
#    'url': 'https://uteoxnpxynnv5889560.cdn.ntruss.com/live/video/ls-20210119171141-j4Tn2/live.mpd'}]}

# %% [markdown]
# 채널 생성

# %%
import sys
import os
import hashlib
import hmac
import base64
import requests
import time
import json

#Time Stamp 생성
timestamp = int(time.time() * 1000)
timestamp = str(timestamp)			

#Access Key
access_key = "cQryoIZzGPyeZbWK7Yin"

#Secret_key
secret_key = "x0ur5FbIfnz0OfduXyevWAjj4cS2XSC5ueHhjwdG"

#Singature Key 생성
def	make_signature():
	timestamp = int(time.time() * 1000)
	timestamp = str(timestamp)

	access_key = "cQryoIZzGPyeZbWK7Yin"			
	secret_key = "x0ur5FbIfnz0OfduXyevWAjj4cS2XSC5ueHhjwdG"	
	secret_key = bytes(secret_key, 'UTF-8')

	method = "POST"
	uri = "/api/v2/channels"

	message = method + " " + uri + "\n" + timestamp + "\n" + access_key
	message = bytes(message, 'UTF-8')
	signingKey = base64.b64encode(hmac.new(secret_key, message, digestmod=hashlib.sha256).digest())
	return signingKey


URL = 'https://livestation.apigw.ntruss.com/api/v2/channels' 

headers = {'x-ncp-apigw-timestamp': timestamp, 
           'x-ncp-iam-access-key': access_key,
           'x-ncp-apigw-signature-v2': make_signature(), 
           'x-ncp-region_code': "KR",
           'Content-Type': 'application/json'
           }
data={  
   "channelName" : "test_gkds",
   "cdn" : {
      "createCdn" : True,
      "cdnType" : "CDN_PLUS"
   },
   "qualitySetId" : 531,
   "useDvr" : False
}

# 'Content-Type': 'application/json; UTF-8'
res = requests.post(URL, headers=headers,data=json.dumps(data))
res.request # 내가 보낸 request 객체에 접근 가능 
res.json()
# Out:
# {'content': {'cdn': {'cdnInstanceNo': 6011784,
#    'cdnType': 'CDN_PLUS',
#    'createCdn': True},
#   'channelId': 'ls-20210206165027-hoqaC',
#   'channelName': 'test_gkds',
#   'immediateOnAir': False,
#   'qualitySetId': 531,
#   'useDvr': False}}
